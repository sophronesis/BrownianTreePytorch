# %%
# Requirements from torch gpu with cuda 10.1
# !pip install torch==1.5.0+cu101 torchvision==0.6.0+cu101 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# Requirement already satisfied: torch==1.5.0+cu101 in /usr/local/lib/python3.6/dist-packages (1.5.0+cu101)
# Requirement already satisfied: torchvision==0.6.0+cu101 in /usr/local/lib/python3.6/dist-packages (0.6.0+cu101)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch==1.5.0+cu101) (0.18.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torch==1.5.0+cu101) (1.18.2)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from torchvision==0.6.0+cu101) (7.0.0)
# WARNING: You are using pip version 20.0.2; however, version 20.1.1 is available.
# You should consider upgrading via the '/usr/bin/python3.6 -m pip install --upgrade pip' command.

# %% [markdown]
# ## Brownian tree with pytorch:

# %%
import numpy as np
import matplotlib.pylab as plt
from tqdm import tqdm
import torch
from torch.nn import functional as F
import utils as ut
import utils_torch as ut_t

# %%
# Constants
gridSize = 301 # grid size (odd)
assert(gridSize % 2 == 1)
percParticles = 10
partNum = gridSize * gridSize * percParticles // 100
iters = 4500
conncetivity = 8
useGPU = True 
useOldMoveFunc = False

# %%
# Device to use
device_name = 'cuda' if useGPU and torch.cuda.is_available() else 'cpu'
device = torch.device(device_name)

# Displacements for getMoveLoc()
disps  = torch.arange(-1, 2).to(device=device)

# Kernel for dilation()
kernel = ut_t.generateKernel(conncetivity).to(device=device)

# Initialisation of fields
ffield, mfield = [np.zeros((gridSize, gridSize), dtype=np.uint8) for i in range(2)]
ffield[gridSize//2, gridSize//2] = 1
ut.placeDots(mfield, partNum)
ffield = torch.Tensor(ffield).type(torch.uint8).to(device=device)
mfield = torch.Tensor(mfield).type(torch.uint8).to(device=device)

# Main cycle
stages = []
for i in tqdm(range(iters)):
    ffield, mfield = ut_t.freezeDots(ffield, mfield, kernel)
    mfield = ut_t.moveDots(mfield, disps, device) if useOldMoveFunc else ut_t.newMoveDots(mfield, device)
    if i % 750 == 0:
        stages.append(ffield.cpu().numpy())
stages.append(ffield.cpu().numpy())
# Out:
# 100%|██████████| 4500/4500 [00:32<00:00, 136.65it/s]

# %% [markdown]
# ### Just a regular visualisation of frozen field containing brownian tree and moving field with particles

# %%
temp = [2 * ffield + mfield]
fig, axs = plt.subplots(1, len(temp), figsize=(20, 20))
for n, i in enumerate(temp):
    axs.imshow(i.cpu().numpy(), cmap=plt.get_cmap("gray"))
plt.show()

# %% [markdown]
# ### Bunch of stacked brownian trees from different time stamps

# %%
temp = np.sum(np.stack(stages), axis=0)
temp[temp>0] += 1
temp = temp + mfield.cpu().numpy().astype(np.int64)
temp = [temp]
fig, axs = plt.subplots(1, len(temp), figsize=(20, 20))
for n, i in enumerate(temp):
    axs.imshow(i, cmap=plt.get_cmap("gist_earth"))
plt.show()

# %% [markdown]
# ### Now let's animate this

# %%
# !sudo apt install ffmpeg -y
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libass9 libavc1394-0 libavdevice57 libavfilter6 libavresample3 libbs2b0
#   libcaca0 libcdio-cdda2 libcdio-paranoia2 libcdio17 libflite1 libfribidi0
#   libiec61883-0 libjack-jackd2-0 libmysofa0 libopenal-data libopenal1
#   libpostproc54 librubberband2 libsamplerate0 libsdl2-2.0-0 libslang2
#   libsndio6.1 libxss1 libxv1
# Suggested packages:
#   ffmpeg-doc jackd2 libportaudio2 sndiod
# The following NEW packages will be installed:
#   ffmpeg libass9 libavc1394-0 libavdevice57 libavfilter6 libavresample3
#   libbs2b0 libcaca0 libcdio-cdda2 libcdio-paranoia2 libcdio17 libflite1
#   libfribidi0 libiec61883-0 libjack-jackd2-0 libmysofa0 libopenal-data
#   libopenal1 libpostproc54 librubberband2 libsamplerate0 libsdl2-2.0-0
#   libslang2 libsndio6.1 libxss1 libxv1
# 0 upgraded, 26 newly installed, 0 to remove and 96 not upgraded.
# Need to get 18.5 MB of archives.
# After this operation, 42.9 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxss1 amd64 1:1.2.2-1 [8582 B]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfribidi0 amd64 0.19.7-2 [24.9 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/main amd64 libslang2 amd64 2.3.1a-3ubuntu1 [424 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/main amd64 libavc1394-0 amd64 0.5.4-4build1 [16.1 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libass9 amd64 1:0.14.0-1 [88.2 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libavresample3 amd64 7:3.4.6-0ubuntu0.18.04.1 [52.6 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libbs2b0 amd64 3.1.0+dfsg-2.2 [10.5 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libflite1 amd64 2.1-release-1 [12.8 MB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libmysofa0 amd64 0.6~dfsg0-2ubuntu0.18.04.1 [38.1 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libpostproc54 amd64 7:3.4.6-0ubuntu0.18.04.1 [50.4 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsamplerate0 amd64 0.1.9-1 [938 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic/universe amd64 librubberband2 amd64 1.8.1-7ubuntu2 [86.7 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libavfilter6 amd64 7:3.4.6-0ubuntu0.18.04.1 [874 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcaca0 amd64 0.99.beta19-2ubuntu0.18.04.1 [203 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcdio17 amd64 1.0.0-2ubuntu2 [58.8 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcdio-cdda2 amd64 10.2+0.94+2-2build1 [17.7 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcdio-paranoia2 amd64 10.2+0.94+2-2build1 [17.2 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic/main amd64 libiec61883-0 amd64 1.2.0-2 [23.5 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic/main amd64 libjack-jackd2-0 amd64 1.9.12~dfsg-2 [263 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libopenal-data all 1:1.18.2-2 [102 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libsndio6.1 amd64 1.1.0-3 [23.4 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libopenal1 amd64 1:1.18.2-2 [266 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libsdl2-2.0-0 amd64 2.0.8+dfsg1-1ubuntu1.18.04.4 [382 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxv1 amd64 2:1.0.11-1 [10.7 kB]
# Get:25 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libavdevice57 amd64 7:3.4.6-0ubuntu0.18.04.1 [75.1 kB]
# Get:26 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 ffmpeg amd64 7:3.4.6-0ubuntu0.18.04.1 [1587 kB]
# Fetched 18.5 MB in 2s (9238 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 26.)
# debconf: falling back to frontend: Readline
#
# 78Selecting previously unselected package libxss1:amd64.
# (Reading database ... 58476 files and directories currently installed.)
# Preparing to unpack .../00-libxss1_1%3a1.2.2-1_amd64.deb ...
# 7Progress: [  0%] [..........................................................] 8Unpacking libxss1:amd64 (1:1.2.2-1) ...
# 7Progress: [  2%] [..........................................................] 87Progress: [  2%] [#.........................................................] 8Selecting previously unselected package libfribidi0:amd64.
# Preparing to unpack .../01-libfribidi0_0.19.7-2_amd64.deb ...
# 7Progress: [  3%] [#.........................................................] 8Unpacking libfribidi0:amd64 (0.19.7-2) ...
# 7Progress: [  5%] [##........................................................] 8Selecting previously unselected package libslang2:amd64.
# Preparing to unpack .../02-libslang2_2.3.1a-3ubuntu1_amd64.deb ...
# 7Progress: [  5%] [###.......................................................] 8Unpacking libslang2:amd64 (2.3.1a-3ubuntu1) ...
# 7Progress: [  6%] [###.......................................................] 8Selecting previously unselected package libavc1394-0:amd64.
# Preparing to unpack .../03-libavc1394-0_0.5.4-4build1_amd64.deb ...
# 7Progress: [  8%] [####......................................................] 8Unpacking libavc1394-0:amd64 (0.5.4-4build1) ...
# 7Progress: [  8%] [####......................................................] 87Progress: [  9%] [#####.....................................................] 8Selecting previously unselected package libass9:amd64.
# Preparing to unpack .../04-libass9_1%3a0.14.0-1_amd64.deb ...
# Unpacking libass9:amd64 (1:0.14.0-1) ...
# 7Progress: [ 11%] [######....................................................] 87Progress: [ 11%] [######....................................................] 8Selecting previously unselected package libavresample3:amd64.
# Preparing to unpack .../05-libavresample3_7%3a3.4.6-0ubuntu0.18.04.1_amd64.deb ...
# 7Progress: [ 12%] [#######...................................................] 8Unpacking libavresample3:amd64 (7:3.4.6-0ubuntu0.18.04.1) ...
# 7Progress: [ 14%] [#######...................................................] 8Selecting previously unselected package libbs2b0:amd64.
# Preparing to unpack .../06-libbs2b0_3.1.0+dfsg-2.2_amd64.deb ...
# 7Progress: [ 15%] [########..................................................] 8Unpacking libbs2b0:amd64 (3.1.0+dfsg-2.2) ...
# 7Progress: [ 15%] [########..................................................] 87Progress: [ 16%] [#########.................................................] 8Selecting previously unselected package libflite1:amd64.
# Preparing to unpack .../07-libflite1_2.1-release-1_amd64.deb ...
# Unpacking libflite1:amd64 (2.1-release-1) ...
# 7Progress: [ 18%] [##########................................................] 87Progress: [ 18%] [##########................................................] 8Selecting previously unselected package libmysofa0:amd64.
# Preparing to unpack .../08-libmysofa0_0.6~dfsg0-2ubuntu0.18.04.1_amd64.deb ...
# 7Progress: [ 19%] [###########...............................................] 8Unpacking libmysofa0:amd64 (0.6~dfsg0-2ubuntu0.18.04.1) ...
# 7Progress: [ 21%] [###########...............................................] 8Selecting previously unselected package libpostproc54:amd64.
# Preparing to unpack .../09-libpostproc54_7%3a3.4.6-0ubuntu0.18.04.1_amd64.deb ...
# 7Progress: [ 21%] [############..............................................] 8Unpacking libpostproc54:amd64 (7:3.4.6-0ubuntu0.18.04.1) ...
# 7Progress: [ 22%] [############..............................................] 8Selecting previously unselected package libsamplerate0:amd64.
# Preparing to unpack .../10-libsamplerate0_0.1.9-1_amd64.deb ...
# 7Progress: [ 24%] [#############.............................................] 8Unpacking libsamplerate0:amd64 (0.1.9-1) ...
# 7Progress: [ 24%] [##############............................................] 87Progress: [ 25%] [##############............................................] 8Selecting previously unselected package librubberband2:amd64.
# Preparing to unpack .../11-librubberband2_1.8.1-7ubuntu2_amd64.deb ...
# Unpacking librubberband2:amd64 (1.8.1-7ubuntu2) ...
# 7Progress: [ 27%] [###############...........................................] 87Progress: [ 27%] [###############...........................................] 8Selecting previously unselected package libavfilter6:amd64.
# Preparing to unpack .../12-libavfilter6_7%3a3.4.6-0ubuntu0.18.04.1_amd64.deb ...
# 7Progress: [ 28%] [################..........................................] 8Unpacking libavfilter6:amd64 (7:3.4.6-0ubuntu0.18.04.1) ...
# 7Progress: [ 29%] [################..........................................] 8Selecting previously unselected package libcaca0:amd64.
# Preparing to unpack .../13-libcaca0_0.99.beta19-2ubuntu0.18.04.1_amd64.deb ...
# 7Progress: [ 31%] [#################.........................................] 8Unpacking libcaca0:amd64 (0.99.beta19-2ubuntu0.18.04.1) ...
# 7Progress: [ 31%] [##################........................................] 87Progress: [ 32%] [##################........................................] 8Selecting previously unselected package libcdio17:amd64.
# Preparing to unpack .../14-libcdio17_1.0.0-2ubuntu2_amd64.deb ...
# Unpacking libcdio17:amd64 (1.0.0-2ubuntu2) ...
# 7Progress: [ 34%] [###################.......................................] 87Progress: [ 34%] [###################.......................................] 8Selecting previously unselected package libcdio-cdda2:amd64.
# Preparing to unpack .../15-libcdio-cdda2_10.2+0.94+2-2build1_amd64.deb ...
# 7Progress: [ 35%] [####################......................................] 8Unpacking libcdio-cdda2:amd64 (10.2+0.94+2-2build1) ...
# 7Progress: [ 37%] [#####################.....................................] 8Selecting previously unselected package libcdio-paranoia2:amd64.
# Preparing to unpack .../16-libcdio-paranoia2_10.2+0.94+2-2build1_amd64.deb ...
# 7Progress: [ 37%] [#####################.....................................] 8Unpacking libcdio-paranoia2:amd64 (10.2+0.94+2-2build1) ...
# 7Progress: [ 38%] [######################....................................] 8Selecting previously unselected package libiec61883-0:amd64.
# Preparing to unpack .../17-libiec61883-0_1.2.0-2_amd64.deb ...
# 7Progress: [ 40%] [#######################...................................] 8Unpacking libiec61883-0:amd64 (1.2.0-2) ...
# 7Progress: [ 40%] [#######################...................................] 87Progress: [ 41%] [#######################...................................] 8Selecting previously unselected package libjack-jackd2-0:amd64.
# Preparing to unpack .../18-libjack-jackd2-0_1.9.12~dfsg-2_amd64.deb ...
# Unpacking libjack-jackd2-0:amd64 (1.9.12~dfsg-2) ...
# 7Progress: [ 43%] [########################..................................] 87Progress: [ 44%] [#########################.................................] 8Selecting previously unselected package libopenal-data.
# Preparing to unpack .../19-libopenal-data_1%3a1.18.2-2_all.deb ...
# 7Progress: [ 44%] [#########################.................................] 8Unpacking libopenal-data (1:1.18.2-2) ...
# 7Progress: [ 45%] [##########################................................] 8Selecting previously unselected package libsndio6.1:amd64.
# Preparing to unpack .../20-libsndio6.1_1.1.0-3_amd64.deb ...
# 7Progress: [ 47%] [###########################...............................] 8Unpacking libsndio6.1:amd64 (1.1.0-3) ...
# 7Progress: [ 47%] [###########################...............................] 87Progress: [ 48%] [###########################...............................] 8Selecting previously unselected package libopenal1:amd64.
# Preparing to unpack .../21-libopenal1_1%3a1.18.2-2_amd64.deb ...
# Unpacking libopenal1:amd64 (1:1.18.2-2) ...
# 7Progress: [ 50%] [############################..............................] 87Progress: [ 50%] [#############################.............................] 8Selecting previously unselected package libsdl2-2.0-0:amd64.
# Preparing to unpack .../22-libsdl2-2.0-0_2.0.8+dfsg1-1ubuntu1.18.04.4_amd64.deb ...
# 7Progress: [ 51%] [#############################.............................] 8Unpacking libsdl2-2.0-0:amd64 (2.0.8+dfsg1-1ubuntu1.18.04.4) ...
# 7Progress: [ 53%] [##############################............................] 8Selecting previously unselected package libxv1:amd64.
# Preparing to unpack .../23-libxv1_2%3a1.0.11-1_amd64.deb ...
# 7Progress: [ 53%] [##############################............................] 8Unpacking libxv1:amd64 (2:1.0.11-1) ...
# 7Progress: [ 54%] [###############################...........................] 8Selecting previously unselected package libavdevice57:amd64.
# Preparing to unpack .../24-libavdevice57_7%3a3.4.6-0ubuntu0.18.04.1_amd64.deb ...
# 7Progress: [ 56%] [################################..........................] 8Unpacking libavdevice57:amd64 (7:3.4.6-0ubuntu0.18.04.1) ...
# 7Progress: [ 56%] [################################..........................] 87Progress: [ 57%] [#################################.........................] 8Selecting previously unselected package ffmpeg.
# Preparing to unpack .../25-ffmpeg_7%3a3.4.6-0ubuntu0.18.04.1_amd64.deb ...
# 7Progress: [ 58%] [#################################.........................] 8Unpacking ffmpeg (7:3.4.6-0ubuntu0.18.04.1) ...
# 7Progress: [ 60%] [##################################........................] 8Setting up libavresample3:amd64 (7:3.4.6-0ubuntu0.18.04.1) ...
# 7Progress: [ 60%] [##################################........................] 87Progress: [ 61%] [###################################.......................] 8Setting up libflite1:amd64 (2.1-release-1) ...
# 7Progress: [ 63%] [####################################......................] 8Setting up libxss1:amd64 (1:1.2.2-1) ...
# 7Progress: [ 63%] [####################################......................] 87Progress: [ 64%] [#####################################.....................] 8Setting up libiec61883-0:amd64 (1.2.0-2) ...
# 7Progress: [ 66%] [######################################....................] 8Setting up libopenal-data (1:1.18.2-2) ...
# 7Progress: [ 66%] [######################################....................] 87Progress: [ 67%] [######################################....................] 8Setting up libbs2b0:amd64 (3.1.0+dfsg-2.2) ...
# 7Progress: [ 69%] [#######################################...................] 8Setting up libavc1394-0:amd64 (0.5.4-4build1) ...
# 7Progress: [ 69%] [########################################..................] 87Progress: [ 70%] [########################################..................] 8Setting up libpostproc54:amd64 (7:3.4.6-0ubuntu0.18.04.1) ...
# 7Progress: [ 72%] [#########################################.................] 8Setting up libfribidi0:amd64 (0.19.7-2) ...
# 7Progress: [ 73%] [##########################################................] 87Progress: [ 73%] [##########################################................] 8Setting up libxv1:amd64 (2:1.0.11-1) ...
# 7Progress: [ 74%] [##########################################................] 8Setting up libsamplerate0:amd64 (0.1.9-1) ...
# 7Progress: [ 76%] [###########################################...............] 87Progress: [ 76%] [############################################..............] 8Setting up libsndio6.1:amd64 (1.1.0-3) ...
# 7Progress: [ 77%] [############################################..............] 8Setting up libslang2:amd64 (2.3.1a-3ubuntu1) ...
# 7Progress: [ 79%] [#############################################.............] 87Progress: [ 79%] [##############################################............] 8Setting up libmysofa0:amd64 (0.6~dfsg0-2ubuntu0.18.04.1) ...
# 7Progress: [ 80%] [##############################################............] 8Setting up libcdio17:amd64 (1.0.0-2ubuntu2) ...
# 7Progress: [ 82%] [###############################################...........] 87Progress: [ 82%] [###############################################...........] 8Setting up libass9:amd64 (1:0.14.0-1) ...
# 7Progress: [ 83%] [################################################..........] 8Setting up libcdio-cdda2:amd64 (10.2+0.94+2-2build1) ...
# 7Progress: [ 85%] [#################################################.........] 87Progress: [ 85%] [#################################################.........] 8Setting up librubberband2:amd64 (1.8.1-7ubuntu2) ...
# 7Progress: [ 86%] [##################################################........] 87Progress: [ 87%] [##################################################........] 8Setting up libsdl2-2.0-0:amd64 (2.0.8+dfsg1-1ubuntu1.18.04.4) ...
# 7Progress: [ 89%] [###################################################.......] 8Setting up libcdio-paranoia2:amd64 (10.2+0.94+2-2build1) ...
# 7Progress: [ 89%] [###################################################.......] 87Progress: [ 90%] [####################################################......] 8Setting up libjack-jackd2-0:amd64 (1.9.12~dfsg-2) ...
# 7Progress: [ 92%] [#####################################################.....] 8Setting up libopenal1:amd64 (1:1.18.2-2) ...
# 7Progress: [ 92%] [#####################################################.....] 87Progress: [ 93%] [######################################################....] 8Setting up libcaca0:amd64 (0.99.beta19-2ubuntu0.18.04.1) ...
# 7Progress: [ 95%] [######################################################....] 8Setting up libavfilter6:amd64 (7:3.4.6-0ubuntu0.18.04.1) ...
# 7Progress: [ 95%] [#######################################################...] 87Progress: [ 96%] [#######################################################...] 8Setting up libavdevice57:amd64 (7:3.4.6-0ubuntu0.18.04.1) ...
# 7Progress: [ 98%] [########################################################..] 8Setting up ffmpeg (7:3.4.6-0ubuntu0.18.04.1) ...
# 7Progress: [ 98%] [#########################################################.] 87Progress: [ 99%] [#########################################################.] 8Processing triggers for libc-bin (2.27-3ubuntu1) ...
#
# 78

# %%
# Device to use
device_name = 'cuda' if useGPU and torch.cuda.is_available() else 'cpu'
device = torch.device(device_name)

# Displacements for getMoveLoc()
disps  = torch.arange(-1, 2).to(device=device)

# Kernel for dilation()
kernel = ut_t.generateKernel(conncetivity).to(device=device)

# Initialisation of fields
ffield, mfield = [np.zeros((gridSize, gridSize), dtype=np.uint8) for i in range(2)]
ffield[gridSize//2, gridSize//2] = 1
ut.placeDots(mfield, partNum)
ffield = torch.Tensor(ffield).type(torch.uint8).to(device=device)
mfield = torch.Tensor(mfield).type(torch.uint8).to(device=device)

# Main cycle
stages = []
for i in tqdm(range(iters)):
    ffield, mfield = ut_t.freezeDots(ffield, mfield, kernel)
    mfield = ut_t.moveDots(mfield, disps, device) if useOldMoveFunc else ut_t.newMoveDots(mfield, device)
    stages.append([ffield.cpu().numpy(), mfield.cpu().numpy()])
# Out:
# 100%|██████████| 4500/4500 [00:35<00:00, 125.84it/s]

# %%
# http://louistiao.me/posts/notebooks/embedding-matplotlib-animations-in-jupyter-notebooks/
import numpy as np
import matplotlib.pyplot as plt

from matplotlib import animation, rc
from IPython.display import HTML

# First set up the figure, the axis, and the plot element we want to animate
fig, ax = plt.subplots()

img = ax.imshow(2 * stages[i][0] + stages[i][1], cmap=plt.get_cmap("gist_earth"))

# initialization function: plot the background of each frame
def init():
    img.set_data(2 * stages[0][0] + stages[0][1])
    return (img,)

# animation function. This is called sequentially
def animate(i):
    img.set_data(2 * stages[i][0] + stages[i][1])
    return (line,)

# call the animator. blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=len(stages), interval=20, blit=True)

HTML(anim.to_html5_video())
